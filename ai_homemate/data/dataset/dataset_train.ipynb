# %%
import pandas as pd
import json

# %%
df = pd.read_csv('C:/Users/whwns/Desktop/데이터/seoul_villa.csv')

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
df
# Out:
#       Unnamed: 0   articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0              0  2344677646       2/4           47              42         2
# 1              1  2345428128       2/4           62              50         3
# 2              2  2345413667       3/4          356              59         2
# 3              3  2345424479       2/4          124              38         1
# 4              4  2345418791      B1/2           41              14         2
# ...          ...         ...       ...          ...             ...       ...
# 7128        7128  2345332318       6/6           46              39         2
# 7129        7129  2345139593       중/5           58              49         2
# 7130        7130  2345111385       2/3           46              46         3
# 7131        7131  2345169473       2/5           65              55         3
# 7132        7132  2345179545       고/5           36              29         2
#
# ...

# %%
df.drop(['Unnamed: 0'],axis = 1, inplace =True)

# %%
df
# Out:
#        articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0     2344677646       2/4           47              42         2
# 1     2345428128       2/4           62              50         3
# 2     2345413667       3/4          356              59         2
# 3     2345424479       2/4          124              38         1
# 4     2345418791      B1/2           41              14         2
# ...          ...       ...          ...             ...       ...
# 7128  2345332318       6/6           46              39         2
# 7129  2345139593       중/5           58              49         2
# 7130  2345111385       2/3           46              46         3
# 7131  2345169473       2/5           65              55         3
# 7132  2345179545       고/5           36              29         2
#
#      bathroomCount  monthlyManagementCost articleName direction  \
# 0                1                  30000          빌라       남서향
# ...

# %%
df.fillna('없음', inplace =True)
df
# Out:
#        articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0     2344677646       2/4           47              42         2
# 1     2345428128       2/4           62              50         3
# 2     2345413667       3/4          356              59         2
# 3     2345424479       2/4          124              38         1
# 4     2345418791      B1/2           41              14         2
# ...          ...       ...          ...             ...       ...
# 7128  2345332318       6/6           46              39         2
# 7129  2345139593       중/5           58              49         2
# 7130  2345111385       2/3           46              46         3
# 7131  2345169473       2/5           65              55         3
# 7132  2345179545       고/5           36              29         2
#
#      bathroomCount monthlyManagementCost articleName direction  \
# 0                1                 30000          빌라       남서향
# ...

# %%
df.iloc[0,0]
# Out:
# 2344677646

# %%
data_train = []

# %%
for i in range(0,10):
    
    qu1 = {
        '질문': '이 집의 해당층/전체층은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,1])
        
      }
    
    
    data_train.append(qu1)
    
    qu2 = {
        '질문': '이 집의 공급면적은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,2])
      }

    data_train.append(qu2)
    
    qu3 = {
        '질문': '이 집의 전용면적은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,3])
      }

    data_train.append(qu3)
    
    qu4 = {
        '질문': '이 집의 방수는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,4])
      }

    data_train.append(qu4)
    
    qu5 = {
        '질문': '이 집의 욕실수는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,5])
      }

    data_train.append(qu5)
    
    qu6 = {
        '질문': '이 집의 월관리비는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,6])
      }

    data_train.append(qu6)
    
    qu7 = {
        '질문': '이 집의 아파트이름과 동은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,7])
      }

    data_train.append(qu7)
    
    qu8 = {
        '질문': '이 집의 방향은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,8])
      }

    data_train.append(qu8)
    
    qu9 = {
        '질문': '이 집의 특징은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,9])
      }

    data_train.append(qu9)
    
    qu10 = {
        '질문': '이 집의 입주가능일은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,10])
      }

    data_train.append(qu10)
    
    qu11 = {
        '질문': '이 집의 총 주차대수 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,11])
      }

    data_train.append(qu11)
    
    qu12 = {
        '질문': '이 집의 1인당 주차대수 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,12])
      }

    data_train.append(qu12)
    
    qu13 = {
        '질문': '이 집을 판매하는 부동산 이름은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,13])
      }

    data_train.append(qu13)
    
    qu14 = {
        '질문': '이 집 판매하는 부동산 번호는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,14])
      }

    data_train.append(qu14)
    
    qu15 = {
        '질문': '이 집의 유형은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,15])
      }

    data_train.append(qu15)
    
    qu16 = {
        '질문': '이 집의 설명은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,16])
      }

    data_train.append(qu16)
    
    qu17 = {
        '질문': '이 집의 거래방식은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,17])
      }

    data_train.append(qu17)
    
    qu18 = {
        '질문': '이 집의 보증금은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,18])
      }

    data_train.append(qu18)
    
    qu19 = {
        '질문': '이 집의 매매가는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,19])
      }

    data_train.append(qu19)
    
    qu20 = {
        '질문': '이 집의 월세는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,20])
      }

    data_train.append(qu20)
    
    qu21 = {
        '질문': '이 집의 내부시설은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,21])
      }

    data_train.append(qu21)
    
    qu22 = {
        '질문': '이 집의 보안 및 기타시설은 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,22])
      }

    data_train.append(qu22)
    
    qu23 = {
        '질문': '이 집의 소재지는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,23])
      }

    data_train.append(qu23)
    
    qu24 = {
        '질문': '이 집의 복층여부는 어떻게 돼?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,24])
      }

    data_train.append(qu24)
    
data_train
# Out:
# [{'질문': '이 집의 해당층/전체층은 어떻게 돼?', '매물번호': '2344677646', '답변': '2/4'},
#  {'질문': '이 집의 공급면적은 어떻게 돼?', '매물번호': '2344677646', '답변': '46.68'},
#  {'질문': '이 집의 전용면적은 어떻게 돼?', '매물번호': '2344677646', '답변': '42.06'},
#  {'질문': '이 집의 방수는 어떻게 돼?', '매물번호': '2344677646', '답변': '2'},
#  {'질문': '이 집의 욕실수는 어떻게 돼?', '매물번호': '2344677646', '답변': '1'},
#  {'질문': '이 집의 월관리비는 어떻게 돼?', '매물번호': '2344677646', '답변': '30000.0'},
#  {'질문': '이 집의 아파트이름과 동은 어떻게 돼?', '매물번호': '2344677646', '답변': '빌라'},
#  {'질문': '이 집의 방향은 어떻게 돼?', '매물번호': '2344677646', '답변': '남서향'},
#  {'질문': '이 집의 특징은 어떻게 돼?', '매물번호': '2344677646', '답변': '없음'},
#  {'질문': '이 집의 입주가능일은 어떻게 돼?', '매물번호': '2344677646', '답변': 'NOW'},
#  {'질문': '이 집의 총 주차대수 어떻게 돼?', '매물번호': '2344677646', '답변': '5.0'},
#  {'질문': '이 집의 1인당 주차대수 어떻게 돼?', '매물번호': '2344677646', '답변': '없음'},
#  {'질문': '이 집을 판매하는 부동산 이름은 어떻게 돼?', '매물번호': '2344677646', '답변': '골드공인중개사사무소'},
#  {'질문': '이 집 판매하는 부동산 번호는 어떻게 돼?', '매물번호': '2344677646', '답변': '02-575-2524'},
# ...

# %%
import jsonlines


with jsonlines.open('output.jsonl', 'w') as writer:
    writer.write_all(data_train)

# %%
from datasets import load_dataset
test_data = load_dataset("json", data_files="output.jsonl")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
test_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['질문', '매물번호', '답변'],
#         num_rows: 240
#     })
# })

# %%
test_data = test_data.map(
     lambda x: 
     {'text': f"### 질문: {x['질문']}\n\n###매물번호: {x['매물번호']}\n\n### 답변: {x['답변']}<|endoftext|>" })
# Out:
# Map:   0%|          | 0/240 [00:00<?, ? examples/s]

# %%
test_data['train'][0]['text']
# Out:
# '### 질문: 이 집의 해당층/전체층은 어떻게 돼?\n\n###매물번호: 2344677646\n\n### 답변: 2/4<|endoftext|>'

# %%
#주변시설 정보 음식점~공원

for i in range(0,10):
    
    qp27 = {
        '질문': '이 집 100m내 음식점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,27])
      }

    data_train.append(qp27)
    
    qp28 = {
        '질문': '이 집 300m내 음식점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,28])
      }

    data_train.append(qp28)
    
    qp29 = {
        '질문': '이 집 500m내 음식점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,29])
      }

    data_train.append(qp29)
    
    qp30 = {
        '질문': '이 집 1000m내 음식점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,30])
      }

    data_train.append(qp30)
    
    qp31 = {
        '질문': '이 집 100m내 헬스장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,31])
      }

    data_train.append(qp31)
    
    qp32 = {
        '질문': '이 집 300m내 헬스장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,32])
      }

    data_train.append(qp32)
    
    qp33 = {
        '질문': '이 집 500m내 헬스장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,33])
      }

    data_train.append(qp33)
    
    qp34 = {
        '질문': '이 집 1000m내 헬스장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,34])
      }

    data_train.append(qp34)
    
    qp35 = {
        '질문': '이 집 100m내 카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,35])
      }

    data_train.append(qp35)
    
    qp36 = {
        '질문': '이 집 300m내 카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,36])
      }

    data_train.append(qp36)
    
    qp37 = {
        '질문': '이 집 500m내 카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,37])
      }

    data_train.append(qp37)
    
    qp38 = {
        '질문': '이 집 1000m내 카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,38])
      }

    data_train.append(qp38)
    
    qp39 = {
        '질문': '이 집 100m내 약국 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,39])
      }

    data_train.append(qp39)
    
    qp40 = {
        '질문': '이 집 300m내 약국 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,40])
      }

    data_train.append(qp40)
    
    qp41 = {
        '질문': '이 집 500m내 약국 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,41])
      }

    data_train.append(qp41)
    
    qp42 = {
        '질문': '이 집 1000m내 약국 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,42])
      }

    data_train.append(qp42)
    
    qp43 = {
        '질문': '이 집 100m내 공원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,43])
      }

    data_train.append(qp43)
    
    qp44 = {
        '질문': '이 집 300m내 공원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,44])
      }

    data_train.append(qp44)
    
    qp45 = {
        '질문': '이 집 500m내 공원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,45])
      }

    data_train.append(qp45)
    
    qp46 = {
        '질문': '이 집 1000m내 공원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,46])
      }

    data_train.append(qp46)

# %%
#주변시설 정보 병원~스터디카페

for i in range(0,10):
    
    qp47 = {
        '질문': '이 집 100m내 병원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,47])
      }

    data_train.append(qp47)
    
    qp48 = {
        '질문': '이 집 300m내 병원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,48])
      }

    data_train.append(qp48)
    
    qp49 = {
        '질문': '이 집 500m내 병원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,49])
      }

    data_train.append(qp49)
    
    qp50 = {
        '질문': '이 집 1000m내 병원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,50])
      }

    data_train.append(qp50)
    
    qp51 = {
        '질문': '이 집 100m내 문화시설 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,51])
      }

    data_train.append(qp51)
    
    qp52 = {
        '질문': '이 집 300m내 문화시설 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,52])
      }

    data_train.append(qp52)
    
    qp53 = {
        '질문': '이 집 500m내 문화시설 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,53])
      }

    data_train.append(qp53)
    
    qp54 = {
        '질문': '이 집 1000m내 문화시설 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,54])
      }

    data_train.append(qp54)
    
    qp55 = {
        '질문': '이 집 100m내 관광명소 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,55])
      }

    data_train.append(qp55)
    
    qp56 = {
        '질문': '이 집 300m내 관광명소 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,56])
      }

    data_train.append(qp56)
    
    qp57 = {
        '질문': '이 집 500m내 관광명소 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,57])
      }

    data_train.append(qp57)
    
    qp58 = {
        '질문': '이 집 1000m내 관광명소 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,58])
      }

    data_train.append(qp58)
    
    qp59 = {
        '질문': '이 집 100m내 독서실 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,59])
      }

    data_train.append(qp59)
    
    qp60 = {
        '질문': '이 집 300m내 독서실 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,60])
      }

    data_train.append(qp60)
    
    qp61 = {
        '질문': '이 집 500m내 독서실 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,61])
      }

    data_train.append(qp61)
    
    qp62 = {
        '질문': '이 집 1000m내 독서실 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,62])
      }

    data_train.append(qp62)
    
    qp63= {
        '질문': '이 집 100m내 스터디카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,63])
      }

    data_train.append(qp63)
    
    qp64 = {
        '질문': '이 집 300m내 스터디카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,64])
      }

    data_train.append(qp64)
    
    qp65 = {
        '질문': '이 집 500m내 스터디카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,65])
      }

    data_train.append(qp65)
    
    qp66 = {
        '질문': '이 집 1000m내 스터디카페 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,66])
      }

    data_train.append(qp66)

# %%
#주변시설 정보 도서관~유치원

for i in range(0,10):
    
    qp67 = {
        '질문': '이 집 100m내 도서관 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,67])
      }

    data_train.append(qp67)
    
    qp68 = {
        '질문': '이 집 300m내 도서관 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,68])
      }

    data_train.append(qp68)
    
    qp69 = {
        '질문': '이 집 500m내 도서관 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,69])
      }

    data_train.append(qp69)
    
    qp70 = {
        '질문': '이 집 1000m내 도서관 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,70])
      }

    data_train.append(qp70)
    
    qp71 = {
        '질문': '이 집 100m내 지하철역 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,71])
      }

    data_train.append(qp71)
    
    qp72 = {
        '질문': '이 집 300m내 지하철역 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,72])
      }

    data_train.append(qp72)
    
    qp73 = {
        '질문': '이 집 500m내 지하철역 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,73])
      }

    data_train.append(qp73)
    
    qp74 = {
        '질문': '이 집 1000m내 지하철역 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,74])
      }

    data_train.append(qp74)
    
    qp75 = {
        '질문': '이 집 100m내 버스정류장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,75])
      }

    data_train.append(qp75)
    
    qp76 = {
        '질문': '이 집 300m내 버스정류장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,76])
      }

    data_train.append(qp76)
    
    qp77 = {
        '질문': '이 집 500m내 버스정류장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,77])
      }

    data_train.append(qp77)
    
    qp78 = {
        '질문': '이 집 1000m내 버스정류장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,78])
      }

    data_train.append(qp78)
    
    qp79 = {
        '질문': '이 집 100m내 어린이집 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,79])
      }

    data_train.append(qp79)
    
    qp80 = {
        '질문': '이 집 300m내 어린이집 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,80])
      }

    data_train.append(qp80)
    
    qp81 = {
        '질문': '이 집 500m내 어린이집 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,81])
      }

    data_train.append(qp81)
    
    qp82 = {
        '질문': '이 집 1000m내 어린이집 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,82])
      }

    data_train.append(qp82)
    
    qp83 = {
        '질문': '이 집 100m내 유치원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,83])
      }

    data_train.append(qp83)
    
    qp84 = {
        '질문': '이 집 300m내 유치원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,84])
      }

    data_train.append(qp84)
    
    qp85 = {
        '질문': '이 집 500m내 유치원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,85])
      }

    data_train.append(qp85)
    
    qp86 = {
        '질문': '이 집 1000m내 유치원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,86])
      }

    data_train.append(qp86)

# %%
#주변시설 정보 초등학교~학원

for i in range(0,10):
    
    qp87 = {
        '질문': '이 집 100m내 초등학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,87])
      }

    data_train.append(qp87)
    
    qp88 = {
        '질문': '이 집 300m내 초등학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,88])
      }

    data_train.append(qp88)
    
    qp89 = {
        '질문': '이 집 500m내 초등학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,89])
      }

    data_train.append(qp89)
    
    qp90 = {
        '질문': '이 집 1000m내 초등학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,90])
      }

    data_train.append(qp90)
    
    qp91 = {
        '질문': '이 집 100m내 중학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,91])
      }

    data_train.append(qp91)
    
    qp92 = {
        '질문': '이 집 300m내 중학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,92])
      }

    data_train.append(qp92)
    
    qp93 = {
        '질문': '이 집 500m내 중학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,93])
      }

    data_train.append(qp93)
    
    qp94 = {
        '질문': '이 집 1000m내 중학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,94])
      }

    data_train.append(qp94)
    
    qp95 = {
        '질문': '이 집 100m내 대학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,95])
      }

    data_train.append(qp95)
    
    qp96 = {
        '질문': '이 집 300m내 대학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,96])
      }

    data_train.append(qp96)
    
    qp97 = {
        '질문': '이 집 500m내 대학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,97])
      }

    data_train.append(qp97)
    
    qp98 = {
        '질문': '이 집 1000m내 버스정류장 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,98])
      }

    data_train.append(qp98)
    
    qp99 = {
        '질문': '이 집 100m내 대학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,99])
      }

    data_train.append(qp99)
    
    qp100 = {
        '질문': '이 집 300m내 대학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,100])
      }

    data_train.append(qp100)
    
    qp101 = {
        '질문': '이 집 500m내 대학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,101])
      }

    data_train.append(qp101)
    
    qp102 = {
        '질문': '이 집 1000m내 대학교 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,102])
      }

    data_train.append(qp102)
    
    qp103 = {
        '질문': '이 집 100m내 학원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,103])
      }

    data_train.append(qp103)
    
    qp104 = {
        '질문': '이 집 300m내 학원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,104])
      }

    data_train.append(qp104)
    
    qp105 = {
        '질문': '이 집 500m내 학원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,105])
      }

    data_train.append(qp105)
    
    qp106 = {
        '질문': '이 집 1000m내 학원 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,106])
      }

    data_train.append(qp106)

# %%
#주변시설 정보 대형마트~마트

for i in range(0,10):
    
    qp107 = {
        '질문': '이 집 100m내 대형마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,107])
      }

    data_train.append(qp107)
    
    qp108 = {
        '질문': '이 집 300m내 대형마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,108])
      }

    data_train.append(qp108)
    
    qp109 = {
        '질문': '이 집 500m내 대형마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,109])
      }

    data_train.append(qp109)
    
    qp110 = {
        '질문': '이 집 1000m내 대형마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,110])
      }

    data_train.append(qp110)
    
    qp111 = {
        '질문': '이 집 100m내 편의점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,111])
      }

    data_train.append(qp111)
    
    qp112 = {
        '질문': '이 집 300m내 편의점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,112])
      }

    data_train.append(qp112)
    
    qp113 = {
        '질문': '이 집 500m내 편의점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,113])
      }

    data_train.append(qp113)
    
    qp114 = {
        '질문': '이 집 1000m내 편의점 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,114])
      }

    data_train.append(qp114)
    
    qp115 = {
        '질문': '이 집 100m내 마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,115])
      }

    data_train.append(qp115)
    
    qp116 = {
        '질문': '이 집 300m내 마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,116])
      }

    data_train.append(qp116)
    
    qp117 = {
        '질문': '이 집 500m내 마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,117])
      }

    data_train.append(qp117)
    
    
    qp118 = {
        '질문': '이 집 1000m내 마트 개수는?',
        '매물번호' : '{0}'.format(df.iloc[i,0]),
        '답변' : '{0}'.format(df.iloc[i,118])
      }

    data_train.append(qp118)

# %%
result = json.dumps(data_train,ensure_ascii=False)
print(result)

# save json
with open(path, 'w') as outfile:
    json.dump(result, outfile, indent=4)

# %%
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# C:\Users\whwns\anaconda3\lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\whwns\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...
