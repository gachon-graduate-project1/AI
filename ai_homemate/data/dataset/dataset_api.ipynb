# %%
import pandas as pd
import requests
import json
import math

pd.options.display.float_format = '{:.7f}'.format
pd.set_option('display.max_columns', None)

# %%
from geopy.geocoders import Nominatim

def geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    geo = geolocoder.geocode(address)
    crd = {"lat": str(geo.latitude), "lng": str(geo.longitude)}

    return crd

crd = geocoding("경기도 가평군 가평읍")
print(crd['lat'])
print(crd['lng'])
# Out:
# 37.825338
# 127.5166062

# %%
df1 = pd.read_csv('C:/Users/whwns/Desktop/데이터/gyeonggi_apart.csv')
df2 = pd.read_csv('C:/Users/whwns/Desktop/데이터/gyeonggi_oneroom.csv')
df3 = pd.read_csv('C:/Users/whwns/Desktop/데이터/gyeonggi_villa.csv')
df4 = pd.read_csv('C:/Users/whwns/Desktop/데이터/seoul_apart.csv')
df5 = pd.read_csv('C:/Users/whwns/Desktop/데이터/seoul_oneroom.csv')
df6 = pd.read_csv('C:/Users/whwns/Desktop/데이터/seoul_villa.csv')
# Out:
# C:\Users\whwns\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6])
df
# Out:
#       Unnamed: 0  articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0              0 2346336695     13/15          108              85         3
# 1              1 2346093188     11/15          108              85         3
# 2              2 2346149353      1/15          108              85         3
# 3              3 2346093467     15/15          145             116         4
# 4              4 2345288490      4/15          108              85         3
# ...          ...        ...       ...          ...             ...       ...
# 7128        7128 2345332318       6/6           46              39         2
# 7129        7129 2345139593       중/5           58              49         2
# 7130        7130 2345111385       2/3           46              46         3
# 7131        7131 2345169473       2/5           65              55         3
# 7132        7132 2345179545       고/5           36              29         2
#
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace = True)
df
# Out:
#       articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0    2346336695     13/15          108              85         3
# 1    2346093188     11/15          108              85         3
# 2    2346149353      1/15          108              85         3
# 3    2346093467     15/15          145             116         4
# 4    2345288490      4/15          108              85         3
# ...         ...       ...          ...             ...       ...
# 7128 2345332318       6/6           46              39         2
# 7129 2345139593       중/5           58              49         2
# 7130 2345111385       2/3           46              46         3
# 7131 2345169473       2/5           65              55         3
# 7132 2345179545       고/5           36              29         2
#
#      bathroomCount  monthlyManagementCost    articleName direction  \
# 0                2                 150000  가평에이원파란채 101동        남향
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#       articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0    2346336695     13/15          108              85         3
# 1    2346093188     11/15          108              85         3
# 2    2346149353      1/15          108              85         3
# 3    2346093467     15/15          145             116         4
# 4    2345288490      4/15          108              85         3
# ...         ...       ...          ...             ...       ...
# 7128 2345332318       6/6           46              39         2
# 7129 2345139593       중/5           58              49         2
# 7130 2345111385       2/3           46              46         3
# 7131 2345169473       2/5           65              55         3
# 7132 2345179545       고/5           36              29         2
#
#      bathroomCount  monthlyManagementCost    articleName direction  \
# 0                2                 150000  가평에이원파란채 101동        남향
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#         index  articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0           0 2346336695     13/15          108              85         3
# 1           1 2346093188     11/15          108              85         3
# 2           2 2346149353      1/15          108              85         3
# 3           3 2346093467     15/15          145             116         4
# 4           4 2345288490      4/15          108              85         3
# ...       ...        ...       ...          ...             ...       ...
# 211290   7128 2345332318       6/6           46              39         2
# 211291   7129 2345139593       중/5           58              49         2
# 211292   7130 2345111385       2/3           46              46         3
# 211293   7131 2345169473       2/5           65              55         3
# 211294   7132 2345179545       고/5           36              29         2
#
#        bathroomCount  monthlyManagementCost    articleName direction  \
# ...

# %%
df.drop(['index'],axis=1,inplace = True)
df
# Out:
# C:\Users\whwns\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         articleNo floorInfo  supplySpace  exclusiveSpace roomCount  \
# 0      2346336695     13/15          108              85         3
# 1      2346093188     11/15          108              85         3
# 2      2346149353      1/15          108              85         3
# 3      2346093467     15/15          145             116         4
# 4      2345288490      4/15          108              85         3
# ...           ...       ...          ...             ...       ...
# 211290 2345332318       6/6           46              39         2
# 211291 2345139593       중/5           58              49         2
# ...

# %%
df.iloc[0,26]
# Out:
# 127.506304

# %%
def search(row, keyword, radius):
    
    
    lat = df.iloc[row,25]
    lng = df.iloc[row,26]
    lat = str(lat)
    lng = str(lng)
        
    radius = str(radius)
        
    length = get_api(keyword, lat, lng, radius)
        
    return length

# %%
def get_api(keyword,lat,lng,radius):

    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword="+keyword+"&location="+lat+'%2C'+lng+"&radius="+radius+"&key=AIzaSyCBQzHqd5F7u8DY3Knq-vEPT6oA63kn-58"
        
    response = requests.get(url).json()
    
    return len(response['results'])

# %%
"""
lat = '38'
lng = '127'


#YOUR_API_KEY = 'AIzaSyCBQzHqd5F7u8DY3Knq-vEPT6oA63kn-58'

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword='음식점'&location="+lat+'%2C'+lng+"&radius=1000&key=AIzaSyCBQzHqd5F7u8DY3Knq-vEPT6oA63kn-58"
        
response = requests.get(url).json()

len(response['results'])
"""
# Out:
# 11

# %%
keywords = ['음식점','헬스장','카페','약국','공원','병원','문화시설','관광명소',
           '독서실','스터디카페','도서관','지하철역','버스정류장','어린이집',
           '유치원','초등학교','중학교','대학교','학원','대형마트','편의점','마트']

radiuss = [100,300,500,1000]




for row in range(0,10):
    for i in keywords:
        for j in radiuss:
            
            column = i+str(j)
            
            num = search(row,i,j)
            df.loc[row,column] = num
# Out:
# C:\Users\whwns\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\whwns\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.to_csv('data_api')
