# %%
import requests
import json
import time
import pandas as pd

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#아예 매물이 없는 경우 조심!!


#서울만 고려했음 바꾸고 싶으면 cortarNo 바꾸기
#'구' 모으기
def get_gungu_info():
    down_url = 'https://new.land.naver.com/api/regions/list?cortarNo=1100000000'
    r = requests.get(down_url,data={"sameAddressGroup":"false"},headers={
    "Accept-Encoding": "gzip, deflate, br",
    "authorization":"Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE2OTU3MDUwMTEsImV4cCI6MTY5NTcxNTgxMX0.mmsIlz-Hg9X-AXo3AJSuL6GYDWZDej9Q8NBdRUUYQqs",
    "Host": "new.land.naver.com",
    "Referer": "https://new.land.naver.com/rooms?ms=37.569925,127.116463,16&a=APT:OPST:ABYG:OBYG:GM:OR:VL:DDDGG:JWJT:SGJT:HOJT&e=RETAIL&aa=SMALLSPCRENT",
    "sec-ch-ua": "'Chromium';v='116', 'Not)A;Brand';v='24', 'Google Chrome';v='116'",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"
    })
    r.encoding = "utf-8-sig"
    temp=json.loads(r.text)
    temp=list(pd.DataFrame(temp['regionList'])["cortarNo"])
    return temp



# '동' 모으기
def get_dong_info(gungu_code):
    down_url = 'https://new.land.naver.com/api/regions/list?cortarNo='+gungu_code
    r = requests.get(down_url,data={"sameAddressGroup":"false"},headers={
    "Accept-Encoding": "gzip, deflate, br",
    "authorization":"Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE2OTU3MDUwMTEsImV4cCI6MTY5NTcxNTgxMX0.mmsIlz-Hg9X-AXo3AJSuL6GYDWZDej9Q8NBdRUUYQqs",
    "Host": "new.land.naver.com",
    "Referer": "https://new.land.naver.com/rooms?ms=37.569925,127.116463,16&a=APT:OPST:ABYG:OBYG:GM:OR:VL:DDDGG:JWJT:SGJT:HOJT&e=RETAIL&aa=SMALLSPCRENT",
    "sec-ch-ua": "'Chromium';v='116', 'Not)A;Brand';v='24', 'Google Chrome';v='116'",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; rv:109.0) Gecko/20100101 Firefox/118.0"
    })
    r.encoding = "utf-8-sig"
    temp=json.loads(r.text)
    temp=list(pd.DataFrame(temp['regionList'])["cortarNo"])
    return temp

# %%
gungu_list=get_gungu_info()
dong_list=get_dong_info(gungu_list[0])
print(dong_list)
# Out:
# ['1168010300', '1168010800', '1168010600', '1168011800', '1168010500', '1168011100', '1168011500', '1168010700', '1168011000', '1168010100', '1168011300', '1168011400', '1168011200', '1168010400']

# %%
#아파트 info에 접근위한 정보 모으기




def get_villa_No(complexNo):
    
    down_url = 'https://new.land.naver.com/api/articles?cortarNo='+complexNo+'&order=rank&realEstateType=VL%3ADDDGG%3AJWJT%3ASGJT%3AHOJT&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&articleState'
    r = requests.get(down_url,headers={

    "Accept": "*/*", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,fr;q=0.6", 
    "authorization":"Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE2OTc2MjE3MTMsImV4cCI6MTY5NzYzMjUxM30.MSwotQag6YkmzP7b5FP41WEeGwhvOwRls8g0qmfEh3A",
    "Host": "new.land.naver.com", 
    "Referer": "https://new.land.naver.com/houses?ms=37.482968,127.0634,16&a=VL:DDDGG:JWJT:SGJT:HOJT&e=RETAIL",
    "Sec-Ch-Ua": '"Google Chrome";v="117", "Not;A=Brand";v="8", "Chromium";v="117"', 
    "Sec-Ch-Ua-Mobile": "?0", 
    "Sec-Fetch-Dest": "empty", 
    "Sec-Fetch-Mode": "cors", 
    "Sec-Fetch-Site": "same-origin", 
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0'
    })
    r.encoding = "utf-8-sig"
    temp=json.loads(r.text)
    temp = list(pd.DataFrame(temp['articleList'])['articleNo'])
    return temp

# %%
articleNo1 = get_villa_No(dong_list[0])
print(articleNo1)
# Out:
# ['2344677646', '2345498350', '2345498817', '2345515685', '2345412212', '2345496356', '2345418791', '2345496838', '2345500402', '2345424479', '2345499261', '2345408117', '2345392986', '2345396388', '2345425942', '2345497918', '2345436258', '2345408218', '2345428128', '2345413667']

# %%
from fake_useragent import UserAgent

ua = UserAgent()
ua.random
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.76'

# %%
def get_villa_info(articleNo):
    
    down_url = 'https://new.land.naver.com/api/articles/'+articleNo+'?complexNo='
    r = requests.get(down_url,headers={

    "Accept": "*/*", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,fr;q=0.6", 
    "authorization":"Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE2OTc2MjE3MTMsImV4cCI6MTY5NzYzMjUxM30.MSwotQag6YkmzP7b5FP41WEeGwhvOwRls8g0qmfEh3A",
    "Host": "new.land.naver.com", 
    "Referer": "https://new.land.naver.com/houses?ms=37.482968,127.0634,16&a=VL:DDDGG:JWJT:SGJT:HOJT&e=RETAIL",
    "Sec-Ch-Ua": '"Google Chrome";v="117", "Not;A=Brand";v="8", "Chromium";v="117"', 
    "Sec-Ch-Ua-Mobile": "?0", 
    "Sec-Fetch-Dest": "empty", 
    "Sec-Fetch-Mode": "cors", 
    "Sec-Fetch-Site": "same-origin", 
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:102.0) Gecko/20100101 Firefox/102.0'
    })
    r.encoding = "utf-8-sig"
    temp=json.loads(r.text)
    
    return temp

# %%
print(articleNo1)
# Out:
# ['2344677646', '2345498350', '2345498817', '2345515685', '2345412212', '2345496356', '2345418791', '2345496838', '2345500402', '2345424479', '2345499261', '2345408117', '2345392986', '2345396388', '2345425942', '2345497918', '2345436258', '2345408218', '2345428128', '2345413667']

# %%
villa_info = get_villa_info(articleNo1[0])
print(villa_info)
# Out:
# {'articleDetail': {'articleNo': '2344677646', 'articleName': '빌라', 'articleSubName': '개포운영', 'cpId': 'bizmk', 'cortarNo': '1168010300', 'nnhscpPlanBildNo': '43343', 'tradeBuildingTypeCode': 'ROOM', 'exposeStartYMD': '20231020', 'exposeEndYMD': '20231119', 'articleConfirmYMD': '20231019', 'tradeCompleteYN': 'N', 'totalDongCount': 0, 'buildingTypeName': '빌라', 'articleStatusCode': 'R0', 'articleTypeCode': 'C02', 'realestateTypeCode': 'VL', 'realestateTypeName': '빌라', 'tradeTypeCode': 'B2', 'tradeTypeName': '월세', 'verificationTypeCode': 'SITE', 'verificationTypeName': '현장', 'applyYN': 'N', 'directTradeYN': 'N', 'mapLocationIndicationYn': 'Y', 'latitude': '37.4769073', 'longitude': '127.0497072', 'pnu': '1168010300112180014', 'cityNo': '1100000000', 'cityName': '서울시', 'divisionName': '강남구', 'sectionName': '개포동', 'realtorId': 'n5724984', 'walkingTimeToNearSubway': 0, 'grandPlanList': [], 'detailAddress': '', 'etcAddress': '201', 'exposureAddress': '서울시 강남구 개포동 1218-14', 'virtualAddressYn': 'N', 'roomCount': '2', 'bathroomCount': '1', 'householdCount': '10', 'moveInTypeCode': 'MV001', 'moveInTypeName': '즉시입주', 'moveInPossibleYmd': 'NOW', 'monthlyManagementCost': 30000, 'buildingSubName': '개포운영', 'buildingTypeCode': 'C0203', 'articleFeatureDescription': '완전 리모델링 하여 상태 최상 입니다', 'detailDescription': '현재 공실이고 완전 리모델링 한 집입니다', 'parkingCount': 5, 'parkingPossibleYN': 'N', 'duplexYN': 'N', 'floorLayerName': '단층', 'hasBuildingUnitInfo': False, 'lawUsage': '공동주택', 'tagList': ['융자금없는', '소형평수', '방두개', '화장실한개'], 'isInterest': False, 'isFalseHoodDeclared': False, 'kisoConnectionYN': 'Y', 'detailAddressYn': 'N', 'isComplex': False, 'isOwnerTradeCompleted': False}, 'articleAddition': {'articleNo': '2344677646', 'articleName': '빌라', 'articleStatus': 'R0', 'realEstateTypeCode': 'VL', 'realEstateTypeName': '빌라', 'articleRealEstateTypeCode': 'C03', 'articleRealEstateTypeName': '빌라/연립', 'tradeTypeCode': 'B2', 'tradeTypeName': '월세', 'verificationTypeCode': 'SITE', 'floorInfo': '2/4', 'rentPrc': '65', 'priceChangeState': 'SAME', 'isPriceModification': False, 'dealOrWarrantPrc': '1억', 'area1': 46, 'area2': 42, 'direction': '남서향', 'articleConfirmYmd': '20231019', 'representativeImgUrl': '/20231019_260/land_naver_1697711582450PLl8L_JPEG/1acf5744087c08be795b556a7cf872b8.JPG', 'representativeImgTypeCode': 'SITE', 'representativeImgThumb': 'f130_98', 'siteImageCount': 10, 'articleFeatureDesc': '완전 리모델링 하여 상태 최상 입니다', 'tagList': ['융자금없는', '소형평수', '방두개', '화장실한개'], 'sameAddrCnt': 1, 'sameAddrDirectCnt': 0, 'sameAddrMaxPrc': '1억/65', 'sameAddrMinPrc': '1억/65', 'cpid': 'bizmk', 'cpName': '매경부동산', 'cpPcArticleUrl': 'http://land.mk.co.kr/rd/rd.php?UID=2344677646', 'cpPcArticleBridgeUrl': '', 'cpPcArticleLinkUseAtArticleTitleYn': False, 'cpPcArticleLinkUseAtCpNameYn': True, 'cpMobileArticleUrl': '', 'cpMobileArticleLinkUseAtArticleTitleYn': False, 'cpMobileArticleLinkUseAtCpNameYn': False, 'latitude': '37.476907', 'longitude': '127.049707', 'isLocationShow': False, 'realtorName': '골드공인중개사사무소', 'realtorId': 'n5724984', 'tradeCheckedByOwner': False, 'isDirectTrade': False, 'isInterest': False, 'isComplex': False}, 'articleFacility': {'directionTypeCode': 'WS', 'directionTypeName': '남서향', 'directionBaseTypeCode': 'BDRM', 'directionBaseTypeName': '안방 기준', 'heatMethodTypeCode': 'HT001', 'heatMethodTypeName': '개별난방', 'heatFuelTypeCode': 'HF001', 'heatFuelTypeName': '도시가스', 'lifeFacilityList': 'LF007,LF015,LF014', 'lifeFacilities': ['신발장', '싱크대', '가스레인지'], 'floorAreaRatio': '-', 'buildingCoverageRatio': '-'}, 'articleFloor': {'totalFloorCount': '4', 'undergroundFloorCount': '-', 'uppergroundFloorCount': '-', 'floorTypeCode': '00', 'floorInputMethodCode': '00', 'correspondingFloorCount': '2'}, 'articleNoneHscp': {}, 'articlePrice': {'rentPrice': 65, 'dealPrice': 0, 'warrantPrice': 10000, 'allWarrantPrice': 0, 'financeTypeCode': '00', 'financePrice': 0, 'premiumPrice': 0, 'isalePrice': 0, 'allRentPrice': 0, 'priceBySpace': 0.0, 'bondPrice': 0, 'middlePayment': 0}, 'articleRealt ...

# %%
"""
apt_info = villa_info


seoul_apart.loc[n,'articleNo'] = apt_info['articleDetail']['articleNo']
                    

seoul_apart.loc[n,'articleNo'] = ""
                

seoul_apart.loc[n,'floorInfo'] = apt_info['articleAddition']['floorInfo']

seoul_apart.loc[n,'floorInfo'] = ""
                    

seoul_apart.loc[n,'supplySpace'] = apt_info['articleSpace']['supplySpace']

seoul_apart.loc[n,'supplySpace'] = ""
                    

seoul_apart.loc[n,'exclusiveSpace'] = apt_info['articleSpace']['exclusiveSpace']

seoul_apart.loc[n,'exclusiveSpace'] = ""
                    

seoul_apart.loc[n,'roomCount'] = apt_info['articleDetail']['roomCount']

seoul_apart.loc[n,'roomCount'] = ""
                

seoul_apart.loc[n,'bathroomCount'] = apt_info['articleDetail']['bathroomCount']

seoul_apart.loc[n,'bathroomCount'] = ""
                    

seoul_apart.loc[n,'monthlyManagementCost'] = apt_info['articleDetail']['monthlyManagementCost']

seoul_apart.loc[n,'monthlyManagementCost'] = ""
                    

seoul_apart.loc[n,'articleName'] = apt_info['articleDetail']['articleName']

seoul_apart.loc[n,'articleName'] = ""
                    

seoul_apart.loc[n,'direction'] = apt_info['articleAddition']['direction']

seoul_apart.loc[n,'direction'] = ""
                

seoul_apart.loc[n,'articleFeatureDes'] = apt_info['articleAddition']['articleFeatureDes']

seoul_apart.loc[n,'articleFeatureDes'] = ""
                

seoul_apart.loc[n,'moveInPossibleYmd'] = apt_info['articleDetail']['moveInPossibleYmd']

seoul_apart.loc[n,'moveInPossibleYmd'] = ""
                

seoul_apart.loc[n,'parkingCount'] = apt_info['articleDetail']['parkingCount']

seoul_apart.loc[n,'parkingCount'] = ""
                            

seoul_apart.loc[n,'parkingPerHouseholdCount'] = apt_info['articleDetail']['parkingPerHouseholdCount']

seoul_apart.loc[n,'parkingPerHouseholdCount'] = ""
                

seoul_apart.loc[n,'realtorName'] = apt_info['articleRealtor']['realtorName']

seoul_apart.loc[n,'realtorName'] = ""

seoul_apart.loc[n,'representativeTelNo'] = apt_info['articleRealtor']['representativeTelNo']

seoul_apart.loc[n,'representativeTelNo'] = ""
                    

seoul_apart.loc[n,'realestateTypeName'] = apt_info['articleDetail']['realestateTypeName']
 
seoul_apart.loc[n,'realestateTypeName'] = ""
                

seoul_apart.loc[n,'detailDescription'] = apt_info['articleDetail']['detailDescription']

seoul_apart.loc[n,'detailDescription'] = ""
                

seoul_apart.loc[n,'tradeTypeName'] = apt_info['articleDetail']['tradeTypeName']

seoul_apart.loc[n,'tradeTypeName'] = ""
                    

seoul_apart.loc[n,'warrantPrice'] = apt_info['articlePrice']['warrantPrice']

seoul_apart.loc[n,'warrantPrice'] = "0"
                    

seoul_apart.loc[n,'dealPrice'] = apt_info['articlePrice']['dealPrice']

seoul_apart.loc[n,'dealPrice'] = "0"
                    

seoul_apart.loc[n,'rentPrice'] = apt_info['articlePrice']['rentPrice']

seoul_apart.loc[n,'rentPrice'] = "0"

seoul_apart.loc[n,'roomFacilities'] = apt_info['articleFacility']['roomFacilities']

seoul_apart.loc[n,'roomFacilities'] = ""
                

seoul_apart.loc[n,'buildingFacilityCodes'] = apt_info['articleFacility']['buildingFacilityCodes']

seoul_apart.loc[n,'buildingFacilityCodes'] = ""
                

seoul_apart.loc[n,'exposureAddress'] = apt_info['articleDetail']['exposureAddress']

seoul_apart.loc[n,'exposureAddress'] = ""
                

seoul_apart.loc[n,'floorLayerName'] = apt_info['articleDetail']['floorLayerName']

seoul_apart.loc[n,'floorLayerName'] = ""

seoul_apart.loc[n,'latitude'] = apt_info['articleDetail']['latitude']

seoul_apart.loc[n,'latitude'] = ""     
                    

seoul_apart.loc[n,'longitude'] = apt_info['articleDetail']['longitude']

seoul_apart.loc[n,'longitude'] = ""   


"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-ce1951fc853f> in <module>
#      48
#      49
# ---> 50 seoul_apart.loc[n,'articleFeatureDes'] = apt_info['articleAddition']['articleFeatureDes']
#      51
#      52 seoul_apart.loc[n,'articleFeatureDes'] = ""
#
# KeyError: 'articleFeatureDes'

# %%
"""
apt_info = villa_info    
    
try:
    seoul_apart.loc[n,'articleNo'] = apt_info['articleDetail']['articleNo']
                    
except:
    seoul_apart.loc[n,'articleNo'] = ""
                
try:
    seoul_apart.loc[n,'floorInfo'] = apt_info['articleAddition']['floorInfo']
except:
    seoul_apart.loc[n,'floorInfo'] = ""
                    
try:
    seoul_apart.loc[n,'supplySpace'] = apt_info['articleSpace']['supplySpace']
except:
    seoul_apart.loc[n,'supplySpace'] = ""
                    
try:
    seoul_apart.loc[n,'exclusiveSpace'] = apt_info['articleSpace']['exclusiveSpace']
except:
    seoul_apart.loc[n,'exclusiveSpace'] = ""
                    
try:
    seoul_apart.loc[n,'roomCount'] = apt_info['articleDetail']['roomCount']
except:
    seoul_apart.loc[n,'roomCount'] = ""
                
try:
    seoul_apart.loc[n,'bathroomCount'] = apt_info['articleDetail']['bathroomCount']
except:
    seoul_apart.loc[n,'bathroomCount'] = ""
                    
try:
    seoul_apart.loc[n,'monthlyManagementCost'] = apt_info['articleDetail']['monthlyManagementCost']
except:
    seoul_apart.loc[n,'monthlyManagementCost'] = ""
                    
try:
    seoul_apart.loc[n,'articleName'] = apt_info['articleDetail']['articleName']
except:
    seoul_apart.loc[n,'articleName'] = ""
                    
try:
    seoul_apart.loc[n,'direction'] = apt_info['articleAddition']['direction']
except:
    seoul_apart.loc[n,'direction'] = ""
            
try:
    seoul_apart.loc[n,'articleFeatureDes'] = apt_info['articleAddition']['articleFeatureDes']
except:
    seoul_apart.loc[n,'articleFeatureDes'] = ""
                
try:
    seoul_apart.loc[n,'moveInPossibleYmd'] = apt_info['articleDetail']['moveInPossibleYmd']
except:
    seoul_apart.loc[n,'moveInPossibleYmd'] = ""
                
try:
    seoul_apart.loc[n,'parkingCount'] = apt_info['articleDetail']['parkingCount']
except:
    seoul_apart.loc[n,'parkingCount'] = ""
                            
try:
    seoul_apart.loc[n,'parkingPerHouseholdCount'] = apt_info['articleDetail']['parkingPerHouseholdCount']
except:
    seoul_apart.loc[n,'parkingPerHouseholdCount'] = ""
                
try:
    seoul_apart.loc[n,'realtorName'] = apt_info['articleRealtor']['realtorName']
except:
    seoul_apart.loc[n,'realtorName'] = ""
                
try:
    seoul_apart.loc[n,'representativeTelNo'] = apt_info['articleRealtor']['representativeTelNo']
except:
    seoul_apart.loc[n,'representativeTelNo'] = ""
                    
try:
    seoul_apart.loc[n,'realestateTypeName'] = apt_info['articleDetail']['realestateTypeName']
except:
    seoul_apart.loc[n,'realestateTypeName'] = ""
                
try:
    seoul_apart.loc[n,'detailDescription'] = apt_info['articleDetail']['detailDescription']
except:
    seoul_apart.loc[n,'detailDescription'] = ""
                
try:
    seoul_apart.loc[n,'tradeTypeName'] = apt_info['articleDetail']['tradeTypeName']
except:
    seoul_apart.loc[n,'tradeTypeName'] = ""
                    
try:
    seoul_apart.loc[n,'warrantPrice'] = apt_info['articlePrice']['warrantPrice']
except:
    seoul_apart.loc[n,'warrantPrice'] = "0"
                    
try:
    seoul_apart.loc[n,'dealPrice'] = apt_info['articlePrice']['dealPrice']
except:
    seoul_apart.loc[n,'dealPrice'] = "0"
                    
try:    
    seoul_apart.loc[n,'rentPrice'] = apt_info['articlePrice']['rentPrice']
except:
    seoul_apart.loc[n,'rentPrice'] = "0"
                
try:
    seoul_apart.loc[n,'roomFacilities'] = apt_info['articleFacility']['roomFacilities']
except:
    seoul_apart.loc[n,'roomFacilities'] = ""
                
try:
    seoul_apart.loc[n,'buildingFacilityCodes'] = apt_info['articleFacility']['buildingFacilityCodes']
except:
    seoul_apart.loc[n,'buildingFacilityCodes'] = ""
                
try:
    seoul_apart.loc[n,'exposureAddress'] = apt_info['articleDetail']['exposureAddress']
except:
    seoul_apart.loc[n,'exposureAddress'] = ""
                
try:
    seoul_apart.loc[n,'floorLayerName'] = apt_info['articleDetail']['floorLayerName']
except:
    seoul_apart.loc[n,'floorLayerName'] = ""
                                
try:
    seoul_apart.loc[n,'latitude'] = apt_info['articleDetail']['latitude']
except:
    seoul_apart.loc[n,'latitude'] = ""     
                    
try:
    seoul_apart.loc[n,'longitude'] = apt_info['articleDetail']['longitude']
except:
    seoul_apart.loc[n,'longitude'] = ""    
    
seoul_apart
"""
# Out:
#     articleNo floorInfo supplySpace exclusiveSpace roomCount bathroomCount  \
# 3  2344677646       2/4       46.68          42.06         2             1
#
#   monthlyManagementCost articleName direction articleFeatureDes  ...  \
# 3                 30000          빌라       남서향                    ...
#
#   tradeTypeName warrantPrice dealPrice rentPrice roomFacilities  \
# 3            월세        10000         0        65
#
#   buildingFacilityCodes      exposureAddress floorLayerName    latitude  \
# 3                        서울시 강남구 개포동 1218-14             단층  37.4769073
#
#      longitude
# 3  127.0497072
#
# [1 rows x 27 columns]

# %%
"""
articleNo : 매물 번호(primary key)
floorInfo : 해당층/총층
supplySpace : 공급면적
exclusiveSpace : 전용면적
roomCount : 방수
bathroomCount : 욕실수
monthlyManagementCost : 월 관리비
articleName : 아파트 이름과 동
direction : 남향
articleFeatureDes : 매물 특징
moveInPossibleYmd : 입주 가능일
parkingCount : 총 주차대수
parkingPerHouseholdCount : 1인당 주차대수
realtorName : 부동산 이름
representativeTelNo : 대표번호
realestateTypeName : 매물 유형
detailDescription : 매물 설명
tradeTypeName : 거래방식
warrantPrice : 보증금
dealPrice : 매매가
rentPrice : 월세
roomFacilities : 내부시설
buildingFacilityCodes : 보안 및 기타시설
exposureAddress : 소재지
floorLayerName : 복층 여부
latitude : 위도
longitude : 경도
"""
# Out:
# '\narticleNo : 매물 번호(primary key)\nfloorInfo : 해당층/총층\nsupplySpace : 공급면적\nexclusiveSpace : 전용면적\nroomCount : 방수\nbathroomCount : 욕실수\nmonthlyManagementCost : 월 관리비\narticleName : 아파트 이름과 동\ndirection : 남향\narticleFeatureDes : 매물 특징\nmoveInPossibleYmd : 입주 가능일\nparkingCount : 총 주차대수\nparkingPerHouseholdCount : 1인당 주차대수\nrealtorName : 부동산 이름\nrepresentativeTelNo : 대표번호\nrealestateTypeName : 매물 유형\ndetailDescription : 매물 설명\ntradeTypeName : 거래방식\nwarrantPrice : 보증금\ndealPrice : 매매가\nrentPrice : 월세\nroomFacilities : 내부시설\nbuildingFacilityCodes : 보안 및 기타시설\nexposureAddress : 소재지\nfloorLayerName : 복층 여부\nlatitude : 위도\nlongitude : 경도\n'

# %%
seoul_apart = pd.DataFrame(columns = ['articleNo','floorInfo','supplySpace','exclusiveSpace','roomCount','bathroomCount',
                                      'monthlyManagementCost','articleName','direction','articleFeatureDes','moveInPossibleYmd',
                                      'parkingCount','parkingPerHouseholdCount','realtorName','representativeTelNo','realestateTypeName',
                                      'detailDescription', 'tradeTypeName','warrantPrice', 'dealPrice','rentPrice','roomFacilities',
                                     'buildingFacilityCodes','exposureAddress','floorLayerName','latitude','longitude'])
seoul_apart
# Out:
# Empty DataFrame
# Columns: [articleNo, floorInfo, supplySpace, exclusiveSpace, roomCount, bathroomCount, monthlyManagementCost, articleName, direction, articleFeatureDes, moveInPossibleYmd, parkingCount, parkingPerHouseholdCount, realtorName, representativeTelNo, realestateTypeName, detailDescription, tradeTypeName, warrantPrice, dealPrice, rentPrice, roomFacilities, buildingFacilityCodes, exposureAddress, floorLayerName, latitude, longitude]
# Index: []
#
# [0 rows x 27 columns]

# %%
n = 0


gungu_list=get_gungu_info()
for i in range(0,len(gungu_list)):
    dong_list=get_dong_info(gungu_list[i])
    
    for j in range(0,len(dong_list)):
        try:
            villa_No_info = get_villa_No(dong_list[j])
        
        except: 
            pass
            
   
    

        for k in range(0,len(villa_No_info)):
            
            
            apt_info = get_villa_info(villa_No_info[k])
            print(villa_No_info[k])
                
          
                          
                
            try:
                seoul_apart.loc[n,'articleNo'] = apt_info['articleDetail']['articleNo']
                    
            except:
                seoul_apart.loc[n,'articleNo'] = ""
                
            try:
                seoul_apart.loc[n,'floorInfo'] = apt_info['articleAddition']['floorInfo']
            except:
                seoul_apart.loc[n,'floorInfo'] = ""
                    
            try:
                seoul_apart.loc[n,'supplySpace'] = apt_info['articleSpace']['supplySpace']
            except:
                seoul_apart.loc[n,'supplySpace'] = ""
                    
            try:
                seoul_apart.loc[n,'exclusiveSpace'] = apt_info['articleSpace']['exclusiveSpace']
            except:
                seoul_apart.loc[n,'exclusiveSpace'] = ""
                    
            try:
                seoul_apart.loc[n,'roomCount'] = apt_info['articleDetail']['roomCount']
            except:
                seoul_apart.loc[n,'roomCount'] = ""
                
            try:
                seoul_apart.loc[n,'bathroomCount'] = apt_info['articleDetail']['bathroomCount']
            except:
                seoul_apart.loc[n,'bathroomCount'] = ""
                    
            try:
                seoul_apart.loc[n,'monthlyManagementCost'] = apt_info['articleDetail']['monthlyManagementCost']
            except:
                seoul_apart.loc[n,'monthlyManagementCost'] = ""
                    
            try:
                seoul_apart.loc[n,'articleName'] = apt_info['articleDetail']['articleName']
            except:
                seoul_apart.loc[n,'articleName'] = ""
                    
            try:
                seoul_apart.loc[n,'direction'] = apt_info['articleAddition']['direction']
            except:
                seoul_apart.loc[n,'direction'] = ""
                
            try:
                seoul_apart.loc[n,'articleFeatureDes'] = apt_info['articleAddition']['articleFeatureDes']
            except:
                seoul_apart.loc[n,'articleFeatureDes'] = ""
                
            try:
                seoul_apart.loc[n,'moveInPossibleYmd'] = apt_info['articleDetail']['moveInPossibleYmd']
            except:
                seoul_apart.loc[n,'moveInPossibleYmd'] = ""
                
            try:
                seoul_apart.loc[n,'parkingCount'] = apt_info['articleDetail']['parkingCount']
            except:
                seoul_apart.loc[n,'parkingCount'] = ""
                            
            try:
                seoul_apart.loc[n,'parkingPerHouseholdCount'] = apt_info['articleDetail']['parkingPerHouseholdCount']
            except:
                seoul_apart.loc[n,'parkingPerHouseholdCount'] = ""
                
            try:
                seoul_apart.loc[n,'realtorName'] = apt_info['articleRealtor']['realtorName']
            except:
                seoul_apart.loc[n,'realtorName'] = ""
                
            try:
                seoul_apart.loc[n,'representativeTelNo'] = apt_info['articleRealtor']['representativeTelNo']
            except:
                seoul_apart.loc[n,'representativeTelNo'] = ""
                    
            try:
                seoul_apart.loc[n,'realestateTypeName'] = apt_info['articleDetail']['realestateTypeName']
            except:
                seoul_apart.loc[n,'realestateTypeName'] = ""
                
            try:
                seoul_apart.loc[n,'detailDescription'] = apt_info['articleDetail']['detailDescription']
            except:
                seoul_apart.loc[n,'detailDescription'] = ""
                
            try:
                seoul_apart.loc[n,'tradeTypeName'] = apt_info['articleDetail']['tradeTypeName']
            except:
                seoul_apart.loc[n,'tradeTypeName'] = ""
                    
            try:
                seoul_apart.loc[n,'warrantPrice'] = apt_info['articlePrice']['warrantPrice']
            except:
                seoul_apart.loc[n,'warrantPrice'] = "0"
                    
            try:
                seoul_apart.loc[n,'dealPrice'] = apt_info['articlePrice']['dealPrice']
            except:
                seoul_apart.loc[n,'dealPrice'] = "0"
                    
            try:    
                seoul_apart.loc[n,'rentPrice'] = apt_info['articlePrice']['rentPrice']
            except:
                seoul_apart.loc[n,'rentPrice'] = "0"
                
            try:
                seoul_apart.loc[n,'roomFacilities'] = apt_info['articleFacility']['roomFacilities']
            except:
                seoul_apart.loc[n,'roomFacilities'] = ""
                
            try:
                seoul_apart.loc[n,'buildingFacilityCodes'] = apt_info['articleFacility']['buildingFacilityCodes']
            except:
                seoul_apart.loc[n,'buildingFacilityCodes'] = ""
                
            try:
                seoul_apart.loc[n,'exposureAddress'] = apt_info['articleDetail']['exposureAddress']
            except:
                seoul_apart.loc[n,'exposureAddress'] = ""
                
            try:
                seoul_apart.loc[n,'floorLayerName'] = apt_info['articleDetail']['floorLayerName']
            except:
                seoul_apart.loc[n,'floorLayerName'] = ""
                                
            try:
                seoul_apart.loc[n,'latitude'] = apt_info['articleDetail']['latitude']
            except:
                seoul_apart.loc[n,'latitude'] = ""     
                    
            try:
                seoul_apart.loc[n,'longitude'] = apt_info['articleDetail']['longitude']
            except:
                seoul_apart.loc[n,'longitude'] = ""     
                              
            n = n+1
# Out:
# 2344677646
# 2345392986
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-0734cf34ccc5> in <module>
#     163             n = n+1
#     164
# --> 165             time.sleep(10)
#
# KeyboardInterrupt:

# %%
seoul_apart
# Out:
#     articleNo floorInfo supplySpace exclusiveSpace roomCount bathroomCount  \
# 0  2344677646       2/4       46.68          42.06         2             1
# 1  2345392986       2/6       65.93          51.78         3             2
#
#   monthlyManagementCost articleName direction articleFeatureDes  ...  \
# 0                 30000          빌라       남서향                    ...
# 1                 60000          빌라       남서향                    ...
#
#   tradeTypeName warrantPrice dealPrice rentPrice roomFacilities  \
# 0            월세        10000         0        65
# 1            매매            0     85000         0
#
#   buildingFacilityCodes      exposureAddress floorLayerName    latitude  \
# 0                        서울시 강남구 개포동 1218-14             단층  37.4769073
# 1                        서울시 강남구 개포동 1164-27             단층  37.4745451
#
#      longitude
# 0  127.0497072
# 1  127.0550862
#
# [2 rows x 27 columns]

# %%
seoul_apart.to_csv('seoul_villa_data.csv')
