# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import urllib.request
import re
import os
from bs4 import BeautifulSoup
import pandas as pd
import random
from selenium.webdriver.common.keys import Keys

# %%
a = random.uniform(0.1,0.2)

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
columns = ['이름','거래방식','가격','소재지','매물번호','층정보','면적',
           '방수','월관리비','방향','매물특징','입주가능일','복층여부',
           '총주차대수','부동산이름','부동산번호','매물설명']


feature_apt = pd.DataFrame(columns = columns)
feature_apt
# Out:
# Empty DataFrame
# Columns: [이름, 거래방식, 가격, 소재지, 매물번호, 층정보, 면적, 방수, 월관리비, 방향, 매물특징, 입주가능일, 복층여부, 총주차대수, 부동산이름, 부동산번호, 매물설명]
# Index: []

# %%
#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(11) > td

# %%
feature_apt
# Out:
# Empty DataFrame
# Columns: [이름, 거래방식, 가격, 소재지, 매물번호, 층정보, 면적, 방수, 월관리비, 방향, 매물특징, 입주가능일, 복층여부, 총주차대수, 부동산이름, 부동산번호, 매물설명]
# Index: []

# %%
def get_info(items, num):
    
    
    
    

    for item in items:
        
        # 방 하나 클릭
        item.click()
        
        
        
        
        # 로드 안될 것을 대비하여 sleep
        time.sleep(random.uniform(0.3,0.4))
        html = driver.page_source
        soup = BeautifulSoup(html,'html.parser')
        
        
        
        if((soup.select_one('#ct > div.map_wrap > div.detail_panel > div > div.detail_contents_inner > div.detail_fixed > div.main_info_area > div.info_title_wrap > h4 > strong')).text) == ('일반원룸' or '단독' or '다가구' or '일반원룸 다가구주택' or '다가구 다가구주택'):
            
            num = num+1
        
     
            name =soup.select_one('#ct > div.map_wrap > div.detail_panel > div > div.detail_contents_inner > div.detail_fixed > div.main_info_area > div.info_title_wrap > h4 > strong').text
            
            feature_apt.loc[num,'이름'] = name
            
            
            try:
                feature_apt.loc[num,'거래방식'] = soup.select_one('#ct > div.map_wrap > div.detail_panel > div > div.detail_contents_inner > div.detail_fixed > div.main_info_area > div.info_article_price > span.type').text
            except:
                feature_apt.loc[num,'거래방식'] = ''
                
            try:
                feature_apt.loc[num,'가격'] = soup.select_one('#ct > div.map_wrap > div.detail_panel > div > div.detail_contents_inner > div.detail_fixed > div.main_info_area > div.info_article_price > span.price').text
            except:
                feature_apt.loc[num,'가격'] = ''
                
            try: 
                feature_apt.loc[num,'소재지'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(1) > td').text
            except:
                feature_apt.loc[num,'소재지'] = ''
                
            try:
                feature_apt.loc[num,'층정보'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(4) > td:nth-child(2)').text
            except:
                feature_apt.loc[num,'층정보'] = ''
            
            try:
                feature_apt.loc[num,'면적'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(3) > td').text
            except:
                feature_apt.loc[num,'면적'] = ''
            
            try:
                feature_apt.loc[num,'방수'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(4) > td:nth-child(4)').text
            except:
                feature_apt.loc[num,'방수'] = ''
                
            try:
                feature_apt.loc[num,'월관리비'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(5) > td:nth-child(2)').text
            except:
                feature_apt.loc[num,'월관리비'] = ''
                
            try:
                feature_apt.loc[num,'매물특징'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(2) > td').text
            except:
                feature_apt.loc[num,'매물특징'] = ''
                
            try:
                feature_apt.loc[num,'입주가능일'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(6) > td:nth-child(2)').text
            except:
                feature_apt.loc[num,'입주가능일'] = ''
            
                
            if(name == '일반원룸 다가구주택' or '일반원룸'):
                
                try:
                    feature_apt.loc[num,'매물번호'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(10) > td:nth-child(2)').text
                except:
                    feature_apt.loc[num,'매물번호'] = ''
                    
                try:
                    feature_apt.loc[num,'방향'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(7) > td:nth-child(2)').text
                except:
                    feature_apt.loc[num,'방향'] = ''
                    
                try:
                    feature_apt.loc[num,'총주차대수'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(10) > td:nth-child(4)').text
                except:
                    feature_apt.loc[num,'총주차대수'] = ''
                 
                try:
                    feature_apt.loc[num, '복층여부'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(9) > td:nth-child(2)').text
                except:
                    feature_apt.loc[num, '복층여부'] = ''
      
                
                
                
                if(soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(12) > td > div > div.info_agent_title') != None):
                    try:
                        feature_apt.loc[num,'매물설명'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(11) > td').text
                    except:
                        feature_apt.loc[num,'매물설명'] = ''
            
                         
                    try:
                        feature_apt.loc[num,'부동산이름'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(12) > td > div > div.info_agent_title > strong').text
                    except:
                        feature_apt.loc[num,'부동산이름'] = ''
                    
                    try:
                        feature_apt.loc[num,'부동산번호'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(12) > td > div > div.info_agent_wrap > dl:nth-child(2) > dd').text
                    except:
                        feature_apt.loc[num,'부동산번호'] = ''
            
               
                    
        
        
                else:
                    try:
                        feature_apt.loc[num,'부동산이름'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(11) > td > div > div.info_agent_title').text
                    except:
                        feature_apt.loc[num,'부동산이름'] = ''
               
                
                    
                    try:
                        feature_apt.loc[num,'부동산번호'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(11) > td > div > div.info_agent_wrap > dl:nth-child(2) > dd').text
                    except:
                        feature_apt.loc[num,'부동산번호'] = ''
                
                    
 ###################################################################################################################################################################################              
            
            else:
                
                try:
                    feature_apt.loc[num,'매물번호'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(12) > td:nth-child(4)').text
                except:
                    feature_apt.loc[num,'매물번호'] = ''
                    
                    
                try:
                    feature_apt.loc[num,'방향'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(7) > td:nth-child(2)').text
                except:
                    feature_apt.loc[num,'방향'] = ''
                    
                try:
                    feature_apt.loc[num,'총주차대수'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(10) > td:nth-child(2)').text
                except:
                    feature_apt.loc[num,'총주차대수'] = ''
                 
                try:
                    feature_apt.loc[num, '복층여부'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(8) > td:nth-child(2)').text
                except: 
                    feature_apt.loc[num, '복층여부'] = ''
      
                
                
                
                if(soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(14) > td > div > div.info_agent_title') != None):
                      
                    try:    
                        feature_apt.loc[num,'매물설명'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(13) > td').text
                    except:
                        feature_apt.loc[num,'매물설명'] = ''
            
                         
                    try:
                        feature_apt.loc[num,'부동산이름'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(13) > td > div > div.info_agent_title > strong').text
                    except:
                        feature_apt.loc[num,'부동산이름'] = ''
                    
                    try:
                        feature_apt.loc[num,'부동산번호'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(13) > td > div > div.info_agent_wrap > dl:nth-child(2) > dd').text
                    except:
                        feature_apt.loc[num,'부동산번호'] = ''
            
                    
        
        
        
                else:
                
                    try:
                        feature_apt.loc[num,'부동산이름'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(13) > td > div > div.info_agent_title').text
                    except:
                        feature_apt.loc[num,'부동산이름'] = ''
               
                
                    
                    try:
                        feature_apt.loc[num,'부동산번호'] = soup.select_one('#detailContents1 > div.detail_box--summary > table > tbody > tr:nth-child(13) > td > div > div.info_agent_wrap > dl:nth-child(2) > dd').text    
                    except:
                        feature_apt.loc[num,'부동산번호'] = ''
            
                    
   
    return num

# %%
b =1
c =1

num = 0

driver = webdriver.Chrome()
url = "https://new.land.naver.com/rooms?ms=37.46561,127.127075,16&a=APT:OPST:ABYG:OBYG:GM:OR:VL:DDDGG:JWJT:SGJT:HOJT&e=RETAIL&aa=SMALLSPCRENT"
driver.get(url)

area_element = driver.find_element(By.CLASS_NAME,"area")
area_element.click()
time.sleep(random.uniform(0.1,0.2))
start_element = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li[1]/label').click()
time.sleep(random.uniform(0.1,0.2))

    
gu_element = driver.find_elements(By.CLASS_NAME,"radio_label_district")
for i in gu_element:
    b = str(b)
    gu = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li['+b+']/label').click()
    b = int(b)
        
    c =1
    b = b+1
        
    time.sleep(random.uniform(0.1,0.2))
    dong_element = driver.find_elements(By.CLASS_NAME,"radio_label_district")
    for j in dong_element:
        c = str(c)
        dong = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li['+c+']/label').click()
        c = int(c)
        
        
        c = c+1
            
        time.sleep(random.uniform(0.1,0.2))
        
            
            
    
        
            
            
        div_element = driver.find_element(By.CLASS_NAME,"item_list.item_list--article")
        item_length = 0
            
            
        while True:
            driver.execute_script("arguments[0].scrollBy(0, 8000)", div_element)
            time.sleep(random.uniform(1,1.3))   
            items = driver.find_elements(By.CLASS_NAME,"item.false")
            if item_length==len(items):
                break
            item_length = len(items)
            
            
        if (len(items)==0):
                
                
            b = b-1
           
                
            close_element = driver.find_element(By.XPATH,'//*[@id="ct"]/div[2]/div[2]/div/button').click()
            area_element = driver.find_element(By.CLASS_NAME,"area")
            area_element.click()
            time.sleep(random.uniform(0.1,0.2))
            start_element = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li[1]/label').click()
            time.sleep(random.uniform(0.3,0.4))
                
            b = str(b)
            gu = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li['+b+']/label').click()
            b = int(b)
                
            time.sleep(random.uniform(0.1,0.2))
                

                
            time.sleep(random.uniform(0.1,0.2))
                
            b = b+1
            
                
                
            continue

                
            
        
        num = get_info(items, num)
            
        
        
            
        b = b-1
        
                
        close_element = driver.find_element(By.XPATH,'//*[@id="ct"]/div[2]/div[2]/div/button').click()
        area_element = driver.find_element(By.CLASS_NAME,"area")
        area_element.click()
        time.sleep(random.uniform(0.1,0.2))
        start_element = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li[1]/label').click()
        time.sleep(random.uniform(0.3,0.4))
                
        b = str(b)
        gu = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li['+b+']/label').click()
        b = int(b)
                
        time.sleep(random.uniform(0.1,0.2))
                
       
                
                
        
                
        b = b+1
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-10-cfd1d53c4beb> in <module>
#      87
#      88
# ---> 89         num = get_info(items, num)
#      90
#      91
#
# <ipython-input-9-e06bb8b63bf0> in get_info(items, num)
#       8
#       9         # 방 하나 클릭
# ---> 10         item.click()
#      11
#      12
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      91     def click(self) -> None:
#      92         """Clicks the element."""
# ---> 93         self._execute(Command.CLICK_ELEMENT)
#      94
#      95     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     392             params = {}
#     393         params["id"] = self._id
# --> 394         return self._parent.execute(command, params)
#     395
# ...

# %%
"""
a =0
b =1
c =1

driver = webdriver.Chrome()
url = "https://new.land.naver.com/complexes?ms=37.482968,127.0634,16&a=APT:ABYG:JGC:PRE:OPST&e=RETAIL"
driver.get(url)

area_element = driver.find_element(By.CLASS_NAME,"area")
area_element.click()
time.sleep(random.uniform(0.1,0.2))
start_element = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li[1]/label').click()
time.sleep(random.uniform(0.1,0.2))
seoul_element = driver.find_elements(By.CLASS_NAME,"radio_label_district")
for gu in seoul_element:
    seoul_element[a].click
    
    time.sleep(random.uniform(0.1,0.2))
    gu_element = driver.find_elements(By.CLASS_NAME,"radio_label_district")
    for dong in gu_element:
        gu_element[b].click()
        
        if(len(gu_element) == b):
            a =a+1
            break
        
        time.sleep(random.uniform(0.1,0.2))
        dong_element = driver.find_elements(By.CLASS_NAME,"complex_title")
        for collection_apt in dong_element:
            dong_element[c].click
            
            
            if(len(dong_element) == c):
                b= b+1
                break
                
            c = c+1
            
            time.sleep(random.uniform(0.2,0.3))
            
            div_element = driver.find_element(By.CLASS_NAME,".item_list.item_list--article")
            item_length = 0

            # 스크롤 다운
            while True:
                driver.execute_script("arguments[0].scrollBy(0, 4000)", div_element)
                time.sleep(0.5)
                items = driver.find_elements(By.CLASS_NAME,".item.false")
                
                #매물이 없는 경우
                if item_length==len(items):
                    close_element = driver.find_element(By.XPATH,'//*[@id="ct"]/div[2]/div[2]/div/button').click()
                    area_element = driver.find_element(By.CLASS_NAME,"area")
                    area_element.click()
                    time.sleep(random.uniform(0.1,0.2))
                    start_element = driver.find_element(By.XPATH,'//*[@id="region_filter"]/div/div/div[2]/ul/li[1]/label').click()
                    time.sleep(random.uniform(0.1,0.2))
                    seoul_element = driver.find_elements(By.CLASS_NAME,"radio_label_district")
                    seoul_element[a].click()
                    gu_element = driver.find_elements(By.CLASS_NAME,"radio_label_district")
                    gu_element[b].click()
                    dong_element = driver.find_elements(By.CLASS_NAME,"complex_title")
                    dong_element[c].click()
                    
                    
                    
                    break
                item_length = len(items)
                for item in items:
                    print(item)
            
            
"""
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-39-c93013a2a27e> in <module>
#      39             time.sleep(random.uniform(0.2,0.3))
#      40
# ---> 41             div_element = driver.find_element(By.CLASS_NAME,".item_list.item_list--article")
#      42             item_length = 0
#      43
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-11c073609ade> in <module>
#       7 html = driver.page_source
#       8 soup = BeautifulSoup(html,'html.parser')
# ----> 9 features = soup.select('.info_table_item.table_td').text
#      10 for feature in features[0,len(features)-1]:
#      11     print(feature)
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# ...

# %%
"""
articleNo : 매물 번호(primary key)
floorInfo : 해당층/총층
supplySpace : 공급면적
exclusiveSpace : 전용면적
roomCount : 방수
bathroomCount : 욕실수
monthlyManagementCost : 월 관리비
articleName : 아파트 이름과 동
direction : 남향
articleFeatureDes : 매물 특징
moveInPossibleYmd : 입주 가능일
parkingCount : 총 주차대수
parkingPerHouseholdCount : 1인당 주차대수
realtorName : 부동산 이름
representativeTelNo : 대표번호
realestateTypeName : 매물 유형
detailDescription : 매물 설명
tradeTypeName : 거래방식
warrantPrice : 보증금
dealPrice : 매매가
rentPrice : 월세
roomFacilities : 내부시설
buildingFacilityCodes : 보안 및 기타시설
exposureAddress : 소재지
floorLayerName : 복층 여부
latitude : 위도
longitude : 경도
"""

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# 원룸
# 빌라
# 아파트
# 끝
# 단독/다가구
# 빌라
# 빌라
# 빌라
# 빌라
# 단독/다가구
# 단독/다가구
# 빌라
# 빌라
# 빌라
# 빌라
# 원룸
# 원룸
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 단독/다가구
# 단독/다가구
# 단독/다가구
# 단독/다가구
# 원룸
# 원룸
# 원룸
# 원룸
# 오피스텔
# 써밋파크 1동
# 오피스텔
# 써밋파크 1동
# 빌라
# 빌라
# 단독/다가구
# 단독/다가구
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 빌라
# 아파트
# 끝
# 아파트
# 끝
# 빌라
# 빌라
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6aefe371a184> in <module>
#       8
#       9     # 로드 안될 것을 대비하여 sleep
# ---> 10     time.sleep(1)
#      11
#      12
#
# KeyboardInterrupt:
